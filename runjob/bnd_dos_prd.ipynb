# %%
import qctoolkit as qtk
import numpy as np
import glob
import os, re
import copy
# Out:
# /home/samio/.local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
cyl_map = {
    'si': [
        ['si', 5.431, [14, 14]],
        ['c', 3.566, [6, 6]],
        ['sic', 4.3596, [14, 6]],
        ['cge', 5.574, [6, 32]],
        ['ge', 5.658, [32, 32]],
        ['sige', 5.432, [14, 32]],
        ['sn', 6.4892, [50, 50]],
        ['snsi', 5.961, [14, 50]],
        ['gesn', 6.0758, [32, 50]],
    ],
    'gaas': [
        ['gaas', 5.6535, [31, 33]],
        ['alp', 5.4635, [13, 15]],
        ['alas', 5.660, [13, 33]],
        ['alsb', 6.1355, [13, 51]],
        ['gap', 5.451, [31, 15]],
        ['gasb', 6.09, [31, 51]],
        ['inp', 5.86, [49, 15]],
        ['inas', 6.05, [49, 33]],
        ['insb', 6.47, [49, 51]],
    ],
    'cdse': [
        ['cdse', 6.08, [48, 34]],
        ['zns', 5.41, [30, 16]],
        ['znse', 5.67, [30, 34]],
        ['znte', 6.1, [30, 52]],
        ['cds', 5.82, [48,16]],
        ['cdte', 6.48, [48, 52]],
        ['hgs', 5.8517, [80, 16]],
        ['hgse', 6.085, [80, 34]],
        ['hgte', 6.453, [80, 52]],
    ]
}

# %% [markdown]
# # pure GGA with insuite restart

# %%
qmsetting = {
    'program': 'abinit',
    'kmesh': [6,6,6],
    'band_scan': [
     [17, 17, 8, 10, 15],
     [[0.25, 0.75, 0.5], # W
      [0.0, 0.0, 0.0],   # Gamma
      [0.0, 0.5, 0.5],   # X
      [0.25, 0.75, 0.5], # L
      [0.5, 0.5, 0.5],   # W
      [0.0, 0.0, 0.0],   # Gamma
     ]],
    'wf_convergence': 1E5,
    'ks_states': 10,
    'link_dep': True, 
    'threads': 1,
}

# %%
# construct crystals based on cyl_map and si, gaas, cdse crystals

mol_base = []
for cyl in ['si', 'gaas', 'cdse']:
    name = 'xyz/%s.xyz' % cyl
    mol_base.append(qtk.Molecule(name))
mol_base

mols_grp = []
for mol in mol_base:
    mol_grp = [mol]
    for info in cyl_map[mol.name][1:]:
        new = mol.copy()
        new.name = info[0]
        new.setCelldm([info[1], info[1], info[1], 0, 0, 0])
        for i in range(new.N):
            if new.Z[i] != info[2][i]:
                new.setAtoms(i, Z=info[2][i])
        mol_grp.append(new)
    mols_grp.append(mol_grp)
    
mols_all = list(qtk.flatten(mols_grp))

# %%
inps = []
for mols in mols_grp:
    for mol_ref in mols:
        for mol_tar in mols:
            #if mol_tar.name != mol_ref.name:
            #print mol_ref.name + '->' + mol_tar.name
            mol = mol_tar.copy()
            mol.name = mol_tar.name + '_' + mol_ref.name
            ref_name = mol_ref.name + '_a-' + mol_tar.name
            ref_path = os.path.abspath('Eg_ref/'+ref_name)
            print ref_path
            inp = qtk.QMInp(
                mol, 
                restart_wavefunction_path = ref_path,
                restart_density_path = ref_path,
                **qmsetting)
            inps.append(inp)
print len(inps)
# Out:
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/si_a-si
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/si_a-c
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/si_a-sic
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/si_a-cge
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/si_a-ge
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/si_a-sige
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/c_a-si
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/c_a-c
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/c_a-sic
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/c_a-cge
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/c_a-ge
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/c_a-sige
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/sic_a-si
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/sic_a-c
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/sic_a-sic
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/sic_a-cge
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/sic_a-ge
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/sic_a-sige
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cge_a-si
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cge_a-c
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cge_a-sic
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cge_a-cge
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cge_a-ge
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cge_a-sige
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/ge_a-si
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/ge_a-c
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/ge_a-sic
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/ge_a-cge
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/ge_a-ge
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/ge_a-sige
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/sige_a-si
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/sige_a-c
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/sige_a-sic
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/sige_a-cge
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/sige_a-ge
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/sige_a-sige
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gaas_a-gaas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gaas_a-alp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gaas_a-alas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gaas_a-alsb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gaas_a-gap
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gaas_a-gasb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gaas_a-inp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gaas_a-inas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gaas_a-insb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alp_a-gaas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alp_a-alp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alp_a-alas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alp_a-alsb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alp_a-gap
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alp_a-gasb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alp_a-inp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alp_a-inas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alp_a-insb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alas_a-gaas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alas_a-alp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alas_a-alas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alas_a-alsb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alas_a-gap
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alas_a-gasb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alas_a-inp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alas_a-inas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alas_a-insb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alsb_a-gaas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alsb_a-alp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alsb_a-alas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alsb_a-alsb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alsb_a-gap
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alsb_a-gasb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alsb_a-inp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alsb_a-inas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/alsb_a-insb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gap_a-gaas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gap_a-alp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gap_a-alas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gap_a-alsb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gap_a-gap
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gap_a-gasb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gap_a-inp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gap_a-inas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gap_a-insb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gasb_a-gaas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gasb_a-alp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gasb_a-alas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gasb_a-alsb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gasb_a-gap
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gasb_a-gasb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gasb_a-inp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gasb_a-inas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/gasb_a-insb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inp_a-gaas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inp_a-alp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inp_a-alas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inp_a-alsb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inp_a-gap
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inp_a-gasb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inp_a-inp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inp_a-inas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inp_a-insb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inas_a-gaas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inas_a-alp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inas_a-alas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inas_a-alsb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inas_a-gap
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inas_a-gasb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inas_a-inp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inas_a-inas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/inas_a-insb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/insb_a-gaas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/insb_a-alp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/insb_a-alas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/insb_a-alsb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/insb_a-gap
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/insb_a-gasb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/insb_a-inp
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/insb_a-inas
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/insb_a-insb
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdse_a-cdse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdse_a-zns
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdse_a-znse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdse_a-znte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdse_a-cds
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdse_a-cdte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdse_a-hgs
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdse_a-hgse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdse_a-hgte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/zns_a-cdse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/zns_a-zns
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/zns_a-znse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/zns_a-znte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/zns_a-cds
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/zns_a-cdte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/zns_a-hgs
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/zns_a-hgse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/zns_a-hgte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znse_a-cdse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znse_a-zns
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znse_a-znse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znse_a-znte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znse_a-cds
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znse_a-cdte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znse_a-hgs
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znse_a-hgse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znse_a-hgte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znte_a-cdse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znte_a-zns
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znte_a-znse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znte_a-znte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znte_a-cds
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znte_a-cdte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znte_a-hgs
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znte_a-hgse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/znte_a-hgte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cds_a-cdse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cds_a-zns
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cds_a-znse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cds_a-znte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cds_a-cds
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cds_a-cdte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cds_a-hgs
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cds_a-hgse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cds_a-hgte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdte_a-cdse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdte_a-zns
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdte_a-znse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdte_a-znte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdte_a-cds
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdte_a-cdte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdte_a-hgs
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdte_a-hgse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/cdte_a-hgte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgs_a-cdse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgs_a-zns
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgs_a-znse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgs_a-znte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgs_a-cds
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgs_a-cdte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgs_a-hgs
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgs_a-hgse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgs_a-hgte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgse_a-cdse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgse_a-zns
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgse_a-znse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgse_a-znte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgse_a-cds
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgse_a-cdte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgse_a-hgs
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgse_a-hgse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgse_a-hgte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgte_a-cdse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgte_a-zns
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgte_a-znse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgte_a-znte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgte_a-cds
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgte_a-cdte
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgte_a-hgs
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgte_a-hgse
# /home/samio/Works/PhD/projects/01_AlGaAs/60_Eg/02_qtkTest/Eg_ref/hgte_a-hgte
# 198

# %% [markdown]
# # HSE06, fresh restart

# %%
qmsetting_base = {
    'program': 'abinit',
    'wf_convergence': 1E5,
    'ks_states': 10,
    'link_dep': True, 
    'threads': 1,
    'restart': True,
    'restart_density': True,
}

qmsetting_bnd = copy.deepcopy(qmsetting_base)
qmsetting_bnd['band_scan'] = [
     [15, 20],
     [[0.5, 0.0, 0.25],  # L
      [0.0, 0.0, 0.0],   # Gamma
      [0.0, 0.5, 0.5],   # X
     ]]

qmsetting_dos = copy.deepcopy(qmsetting_base)
qmsetting_dos['dos_mesh'] = [12, 12, 12]

# %%
# construct crystals based on cyl_map and si, gaas, cdse crystals

mol_base = []
#for cyl in ['si', 'gaas', 'cdse']:
for cyl in ['si', 'gaas']:
    name = 'xyz/%s.xyz' % cyl
    mol_base.append(qtk.Molecule(name))
mol_base

mols_grp = []
for mol in mol_base:
    mol_grp = [mol]
    for info in cyl_map[mol.name][1:]:
        new = mol.copy()
        new.name = info[0]
        new.setCelldm([info[1], info[1], info[1], 0, 0, 0])
        for i in range(new.N):
            if new.Z[i] != info[2][i]:
                new.setAtoms(i, Z=info[2][i])
        mol_grp.append(new)
    mols_grp.append(mol_grp)
    
mols_all = list(qtk.flatten(mols_grp))

ref_bnd_path = 'Eg_ref_vary_a_bnd_rst'
ref_dos_path = 'Eg_ref_vary_a_dos_rst'
bnd = 'Eg_prd_bnd'
dos = 'Eg_prd_dos'

# %%
inps_bnd = []
inps_dos = []
for mols in mols_grp:
    cyl_names = [_[0] for _ in cyl_map[mols[0].name]]
    for mol_ref in mols:
        for mol_tar in mols:
            for mol_rst in mols:
                
                mol = mol_tar.copy()
                mol.name = mol_tar.name + '_r-' + mol_rst.name + '_a-' + mol_ref.name
                
                # use ref as geometry scan
                ind = cyl_names.index(mol_ref.name)
                a0 = cyl_map[mols[0].name][ind][1]
                mol.setCelldm([a0, a0, a0, 0, 0, 0])
                
                # use reference system with target geometry
                rst_name = mol_rst.name + '_a-' + mol_ref.name
                rst_path_bnd = os.path.abspath(ref_bnd_path + '/' + rst_name)
                rst_path_dos = os.path.abspath(ref_dos_path + '/' + rst_name)

                # band scan restart
                inp_b = qtk.QMInp(
                    mol,
                    restart_wavefunction_path = rst_path_bnd,
                    restart_density_path = rst_path_bnd,
                    **qmsetting_bnd)
                inps_bnd.append(inp_b)

                # DOS restart
                inp_d = qtk.QMInp(
                    mol,
                    restart_wavefunction_path = rst_path_dos,
                    restart_density_path = rst_path_dos,
                    **qmsetting_dos)
                inps_dos.append(inp_d)
            
print len(inps_bnd)
# Out:
# 1458
